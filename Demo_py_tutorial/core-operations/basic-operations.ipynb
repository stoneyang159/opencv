# %%
import numpy as np
import cv2 as cv

# %%
img = cv.imread('/data/file/img/data/messi5.jpg')

# %%
px = img[100, 100]
px
# Out:
# array([157, 166, 200], dtype=uint8)

# %%
img.shape
# Out:
# (342, 548, 3)

# %%
blue = img[100, 100, 0]
blue
# Out:
# 157

# %%
img[100, 100] = [255, 255, 255]
img[100, 100]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
img.item(10, 10, 2)
# Out:
# 59

# %%
img.itemset((10, 10, 2), 100)
img.item(10, 10, 2)
# Out:
# 100

# %%
ball = img[280:340, 330:390]
img[273:333, 100:160] = ball

# %%
from matplotlib import pyplot as plt

# %%
plt.subplot(111)
plt.imshow(img)
plt.title('ORIGINAL')
# Out:
# Text(0.5, 1.0, 'ORIGINAL')

# %%
b, g, r = cv.split(img)

# %%
b.shape
# Out:
# (342, 548)

# %%
BLUE = [255,0,0]
img1 = cv.imread('/data/file/img/data/opencv-logo.png')

# %%
replicate = cv.copyMakeBorder(img1, 10, 10, 10, 10, cv.BORDER_REPLICATE)
plt.subplot(111)
plt.imshow(replicate)
plt.title('replicate')
# Out:
# Text(0.5, 1.0, 'replicate')
