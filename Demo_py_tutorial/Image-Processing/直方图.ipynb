# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('/data/file/img/data/home.jpg', 0)

# %%
img.shape
# Out:
# (384, 512)

# %%
hist = cv.calcHist([img], [0], None, [256], [0, 256])

# %%
hist.shape
# Out:
# (256, 1)

# %%
plt.hist(img.ravel(), 256, [0, 256])
plt.show()

# %%
img.ravel()
# Out:
# array([ 88,  87,  85, ..., 174, 174, 174], dtype=uint8)
