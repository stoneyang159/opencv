# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img1 = cv.imread('/data/file/img/data/messi5.png')
res = cv.resize(img1, None, fx=2, fy=2, interpolation=cv.INTER_CUBIC)
cv.imshow('res', res)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-9945725aee6a> in <module>
#       1 img1 = cv.imread('/data/file/img/data/messi5.png')
# ----> 2 res = cv.resize(img1, None, fx=2, fy=2, interpolation=cv.INTER_CUBIC)
#       3 cv.imshow('res', res)
#       4 cv.waitKey(0)
#       5 cv.destroyAllWindows()
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-eirhwqtr/opencv/modules/imgproc/src/resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
img = cv.imread('/data/file/img/data/messi5.jpg',0)
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv.warpAffine(img,M,(cols,rows))
cv.imshow('img',dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
rows,cols = img.shape
# cols-1 and rows-1 are the coordinate limits.
M = cv.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),90,1)
dst = cv.warpAffine(img,M,(cols,rows))
cv.imshow('img',dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread('/data/file/img/data/left01.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
M = cv.getAffineTransform(pts1,pts2)
dst = cv.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
